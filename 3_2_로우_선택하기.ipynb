# %% [markdown]
# <a href="https://colab.research.google.com/github/seomj0914/MyStudy/blob/main/3_2_%EB%A1%9C%EC%9A%B0_%EC%84%A0%ED%83%9D%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv')

# %% [markdown]
# #35세 초과인 승객 확인하기

# %%
titanic ['Age'] > 35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic[titanic ['Age'] > 35]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
above_35 = titanic[titanic ['Age'] > 35]
above_35.shape
# Out:
# (217, 12)

# %% [markdown]
# #Pclass 선택하기

# %% [markdown]
# SQL
#
# SELECT *
#
# FROM titanic
#
# WHERE Age > 35
#
# -WHERE Pclass IN (2,3)
#
# -WHERE Pclass = 2 OR Pclass = 3
#
# -WHERE Pclass = 2 AND Pclass = 3

# %%
titanic ['Pclass'].isin([2,3])
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Pclass, Length: 891, dtype: bool

# %%
titanic[titanic ['Pclass'].isin([2,3])] # 2 또는 3 과  동일
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titanic[(titanic['Pclass'] == 2) | (titanic['Pclass'] == 3 )]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titanic[(titanic['Pclass'] == 2) & (titanic['Age'] == 30 )]
# Out:
#      PassengerId  Survived  Pclass  \
# 178          179         0       2
# 213          214         0       2
# 219          220         0       2
# 308          309         0       2
# 322          323         1       2
# 418          419         0       2
# 726          727         1       2
# 747          748         1       2
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 178                           Hale, Mr. Reginald    male  30.0      0      0
# 213                  Givard, Mr. Hans Kristensen    male  30.0      0      0
# 219                           Harris, Mr. Walter    male  30.0      0      0
# 308                          Abelson, Mr. Samuel    male  30.0      1      0
# 322                    Slayter, Miss. Hilda Mary  female  30.0      0      0
# 418                   Matthews, Mr. William John    male  30.0      0      0
# 726  Renouf, Mrs. Peter Henry (Lillian Jefferys)  female  30.0      3      0
# ...
