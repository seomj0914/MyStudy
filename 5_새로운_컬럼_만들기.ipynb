# %% [markdown]
# <a href="https://colab.research.google.com/github/seomj0914/MyStudy/blob/main/5_%EC%83%88%EB%A1%9C%EC%9A%B4_%EC%BB%AC%EB%9F%BC_%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
air_quality = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/air_quality_no2.csv')
air_quality
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
air_quality.shape
# Out:
# (1035, 4)

# %% [markdown]
# #기존 컬럼에 숫자 곱하기

# %%
air_quality['london_mg_per_cubic'] = air_quality['station_london']*1.882

# %%
air_quality
# Out:
#                  datetime  station_antwerp  station_paris  station_london  \
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
#       london_mg_per_cubic
# 0                  43.286
# ...

# %%
a = [1,2,3,4]
a
# Out:
# [1, 2, 3, 4]

# %%
a*2
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
b = []
for i in a :
     b.append(i * 2)

# %%
b
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# #컬럼끼리 연산하기

# %%
 air_quality['ratio_paris_antwerp'] = air_quality['station_paris']/air_quality['station_antwerp']

# %%
air_quality
# Out:
#                  datetime  station_antwerp  station_paris  station_london  \
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
#       ratio_paris_antwerp
# 0                     NaN
# ...

# %%
air_quality[air_quality['station_antwerp']>30]
# Out:
#                 datetime  station_antwerp  station_paris  station_london  \
# 1    2019-05-07 03:00:00             50.5           25.0            19.0
# 2    2019-05-07 04:00:00             45.0           27.7            19.0
# 265  2019-05-18 03:00:00             41.5           37.4            31.0
# 282  2019-05-18 20:00:00             35.5           14.5            36.0
# 283  2019-05-18 21:00:00             35.5           67.5            35.0
# 284  2019-05-18 22:00:00             40.0           36.2            41.0
# 285  2019-05-18 23:00:00             39.0           59.3            46.0
# 286  2019-05-19 00:00:00             34.5           62.5            46.0
# 294  2019-05-19 08:00:00             30.5           31.1            36.0
# 303  2019-05-19 17:00:00             33.0           31.7            28.0
# 319  2019-05-20 09:00:00             38.0           46.9            29.0
# 320  2019-05-20 10:00:00             40.0           46.1            29.0
# ...

# %% [markdown]
# #칼럼 이름 수정하기

# %%
 air_quality_renamed = air_quality.rename(columns={'station_paris':'FR04014'})

# %%
air_quality_renamed
# Out:
#                  datetime  station_antwerp  FR04014  station_london  \
# 0     2019-05-07 02:00:00              NaN      NaN            23.0
# 1     2019-05-07 03:00:00             50.5     25.0            19.0
# 2     2019-05-07 04:00:00             45.0     27.7            19.0
# 3     2019-05-07 05:00:00              NaN     50.4            16.0
# 4     2019-05-07 06:00:00              NaN     61.9             NaN
# ...                   ...              ...      ...             ...
# 1030  2019-06-20 22:00:00              NaN     21.4             NaN
# 1031  2019-06-20 23:00:00              NaN     24.9             NaN
# 1032  2019-06-21 00:00:00              NaN     26.5             NaN
# 1033  2019-06-21 01:00:00              NaN     21.8             NaN
# 1034  2019-06-21 02:00:00              NaN     20.0             NaN
#
#       ratio_paris_antwerp
# 0                     NaN
# 1                0.495050
# 2                0.615556
# 3                     NaN
# ...

# %%
 #컬럼명 다 소문자로 변경
air_quality_renamed_lower = air_quality.rename(columns=str.lower)
 #컬럼명 다 대문자로 변경
air_quality_renamed_upper = air_quality.rename(columns=str.upper)
